# %% [markdown]
# # NTUT DRL Homework 2: CarRacing
#
# CarRacing is the continuous control task learning from pixels, a top-down racing environment. State consists of 96x96 pixels. Reward is -0.1 every frame and +1000/N for every track tile visited, where N is the total number of tiles in track. For example, if you have finished in 732 frames, your reward is 1000 - 0.1*732 = 926.8 points. CarRacing-v0 defines "solving" as getting average reward of 900 over 100 consecutive trials.
# This example notebook refers to the github:
#
# https://github.com/Rafael1s/Deep-Reinforcement-Learning-Udacity/tree/master/CarRacing-From-Pixels-PPO

# %% [markdown]
# ### Install video rendering dependancies, which takes around 45 seconds

# %%
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get update  > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg  > /dev/null 2>&1

# %%
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import tensorflow as tf
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %% [markdown]
# ### Video Display Functions

# %%
def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
# Install CarRacing environment (in Box2D)
# !pip install Box2D
# Out:
# Collecting Box2D
#   Downloading Box2D-2.3.10-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.9 MB/s eta 0:00:01
# Installing collected packages: Box2D
# Successfully installed Box2D-2.3.10

# %%
env = wrap_env(gym.make("CarRacing-v0"))

# %%
# Test Environment and Show Videos
observation = env.reset()
while True:
    env.render()
    action = env.action_space.sample() 
    observation, reward, done, info = env.step(action)         
    if done: 
      break;
env.close()
show_video()
# Out:
# Track generation: 1175..1473 -> 298-tiles track
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Import Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Beta
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler
import time
from collections import deque

# %%
class Net(nn.Module):
    """
    Convolutional Neural Network for PPO
    """

    def __init__(self, img_stack):
        super(Net, self).__init__()
        self.cnn_base = nn.Sequential(  # input shape (4, 96, 96)
            nn.Conv2d(img_stack, 8, kernel_size=4, stride=2),
            nn.ReLU(),  # activation
            nn.Conv2d(8, 16, kernel_size=3, stride=2),  # (8, 47, 47)
            nn.ReLU(),  # activation
            nn.Conv2d(16, 32, kernel_size=3, stride=2),  # (16, 23, 23)
            nn.ReLU(),  # activation
            nn.Conv2d(32, 64, kernel_size=3, stride=2),  # (32, 11, 11)
            nn.ReLU(),  # activation
            nn.Conv2d(64, 128, kernel_size=3, stride=1),  # (64, 5, 5)
            nn.ReLU(),  # activation
            nn.Conv2d(128, 256, kernel_size=3, stride=1),  # (128, 3, 3)
            nn.ReLU(),  # activation
        )  # output shape (256, 1, 1)
        self.v = nn.Sequential(nn.Linear(256, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(256, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

    def forward(self, x):
        x = self.cnn_base(x)
        x = x.view(-1, 256)
        v = self.v(x)
        x = self.fc(x)
        alpha = self.alpha_head(x) + 1
        beta = self.beta_head(x) + 1

        return (alpha, beta), v

# %%
img_stack=4

transition = np.dtype([('s', np.float64, (img_stack, 96, 96)), 
                       ('a', np.float64, (3,)), ('a_logp', np.float64),
                       ('r', np.float64), ('s_', np.float64, (img_stack, 96, 96))])

GAMMA=0.99
EPOCH= 8 # beter than 10
MAX_SIZE = 2000 ## CUDA out of mem for max_size=10000
BATCH=128 
EPS=0.1
LEARNING_RATE = 0.001 # bettr than 0.005 or 0.002 

class Agent():
    """ Agent for training """
    
    def __init__(self, device):
        self.training_step = 0
        self.net = Net(img_stack).double().to(device)
        self.buffer = np.empty(MAX_SIZE, dtype=transition)
        self.counter = 0
        self.device = device
        
        self.optimizer = optim.Adam(self.net.parameters(), lr=LEARNING_RATE)  ## lr=1e-3

    def select_action(self, state):
        state = torch.from_numpy(state).double().to(self.device).unsqueeze(0)
        
        with torch.no_grad():
            alpha, beta = self.net(state)[0]
        dist = Beta(alpha, beta)
        action = dist.sample()
        a_logp = dist.log_prob(action).sum(dim=1)

        action = action.squeeze().cpu().numpy()
        a_logp = a_logp.item()
        return action, a_logp


    def store(self, transition):
        self.buffer[self.counter] = transition
        self.counter += 1
        if self.counter == MAX_SIZE:
            self.counter = 0
            return True
        else:
            return False

    def update(self):
        self.training_step += 1

        s = torch.tensor(self.buffer['s'], dtype=torch.double).to(self.device)
        a = torch.tensor(self.buffer['a'], dtype=torch.double).to(self.device)
        r = torch.tensor(self.buffer['r'], dtype=torch.double).to(self.device).view(-1, 1)
        next_s = torch.tensor(self.buffer['s_'], dtype=torch.double).to(self.device)

        old_a_logp = torch.tensor(self.buffer['a_logp'], dtype=torch.double).to(self.device).view(-1, 1)

        with torch.no_grad():
            target_v = r + GAMMA * self.net(next_s)[1]
            adv = target_v - self.net(s)[1]
            # adv = (adv - adv.mean()) / (adv.std() + 1e-8)

        for _ in range(EPOCH):
            for index in BatchSampler(SubsetRandomSampler(range(MAX_SIZE)), BATCH, False):

                alpha, beta = self.net(s[index])[0]
                dist = Beta(alpha, beta)
                a_logp = dist.log_prob(a[index]).sum(dim=1, keepdim=True)
                ratio = torch.exp(a_logp - old_a_logp[index])

                surr1 = ratio * adv[index]
                
                # clipped function
                surr2 = torch.clamp(ratio, 1.0 - EPS, 1.0 + EPS) * adv[index]
                action_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.smooth_l1_loss(self.net(s[index])[1], target_v[index])
                loss = action_loss + 2. * value_loss

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

# %% [markdown]
# ### Initializing Training Environment

# %%
# Initializing Training Environment
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('device: ', device)

seed = 0 
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)

action_repeat = 10
env = gym.make('CarRacing-v0', verbose=0)
state = env.reset()
print('env.action_space.shape: ', env.action_space.shape)
reward_threshold = env.spec.reward_threshold
print('reward_threshold', reward_threshold)
# Out:
# device:  cpu
# env.action_space.shape:  (3,)
# reward_threshold 900

# %% [markdown]
# ### Preprocessing CarRacing Screenshots

# %%
# show what a preprocessed image looks like
frame, _, _, _ = env.step(np.array([2., 1., 1.]))

print('frame.shape: ', frame.shape)
plt.subplot(1,2,1)
plt.imshow(frame)
plt.title('original image')

#-------------------------------#

def rgb2gray(rgb, norm=True):
        # rgb image -> gray [0, 1]
    gray = np.dot(rgb[..., :], [0.299, 0.587, 0.114])
    if norm:
        # normalize
        gray = gray / 128. - 1.
    return gray

img_gray = rgb2gray(frame)

#-------------------------------# 
plt.subplot(1,2,2)
plt.title('preprocessed image')

print('img.shape: ', img_gray.shape)

# 96 x 96 black and white image
plt.imshow(img_gray, cmap='Greys')
plt.show()
# Out:
# frame.shape:  (96, 96, 3)
# img.shape:  (96, 96)

# %% [markdown]
# ### Define Wrapper for Our Environment

# %%
class Wrapper():
    """
    Environment wrapper for CarRacing 
    """

    def __init__(self, env):
        self.env = env  

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()

        self.die = False
        img_rgb = env.reset()
        img_gray = rgb2gray(img_rgb)
        self.stack = [img_gray] * img_stack  # four frames for decision
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(action_repeat):
            img_rgb, reward, die, _ = env.step(action)
            # don't penalize "die state"
            if die:
                reward += 100
            # green penalty
            if np.mean(img_rgb[:, :, 1]) > 185.0:
                reward -= 0.05
            total_reward += reward
            # if no reward recently, end the episode
            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break
        img_gray = rgb2gray(img_rgb)
        self.stack.pop(0)
        self.stack.append(img_gray)
        assert len(self.stack) == img_stack
        return np.array(self.stack), total_reward, done, die


    @staticmethod
    def reward_memory():
        # record reward for last 100 steps
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory

# %%
def save(agent, directory, filename, suffix):
    torch.save(agent.net.state_dict(), '%s/%s_%s.pth' % (directory, filename, suffix))

# %%
def ppo_train(n_episodes=500, save_every=100):
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    

    timestep_after_last_save = 0
    
    time_start = time.time()

    running_score = 0
    state = env_wrap.reset()
    
    i_lim = 0
    
    for i_episode in range(n_episodes):
        
        timestep = 0
        total_reward = 0
        
        ## score = 0
        state = env_wrap.reset()

        while True:    
            
            action, a_logp = agent.select_action(state)
            next_state, reward, done, die = env_wrap.step( 
                action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

            if agent.store((state, action, a_logp, reward, next_state)):
                print('updating')
                agent.update()
            
            total_reward += reward
            state = next_state
            
            timestep += 1  
            timestep_after_last_save += 1
            
            if done or die:
                break
                
        running_score = running_score * 0.99 + total_reward * 0.01

        scores_deque.append(total_reward)
        scores_array.append(total_reward)

        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)
        
        s = (int)(time.time() - time_start)        
        print('Ep. {}, Ep.Timesteps {}, Score: {:.2f}, Avg.Score: {:.2f}, Run.Score {:.2f}, \
Time: {:02}:{:02}:{:02} '\
            .format(i_episode, timestep, \
                    total_reward, avg_score, running_score, s//3600, s%3600//60, s%60))  
       
        
        # Save episode is equal to "save_every" timesteps
        if i_episode+1 % save_every == 0:

            suf = str(i_episode)
            save(agent, '', 'model_weights', suf)
            
        if np.mean(scores_deque) > reward_threshold:
            print("Solved environment! Running score is {:.2f}, Avg.Score: {:.2f} !" \
                  .format(running_score, avg_score))
            break
            
    return scores_array, avg_scores_array

# %% [markdown]
# ### Training Agent

# %%
agent = Agent(device)

env_wrap = Wrapper(env)

NUM_EPISODES = 300

scores, avg_scores  = ppo_train(NUM_EPISODES)
# Save latest model. We'll use it for testing
save(agent, '.', 'model_weights', 'latest')
# Out:
# Ep. 0, Ep.Timesteps 84, Score: -21.39, Avg.Score: -21.39, Run.Score -0.21, Time: 00:00:19
# Ep. 1, Ep.Timesteps 88, Score: -18.02, Avg.Score: -19.71, Run.Score -0.39, Time: 00:00:38
# Ep. 2, Ep.Timesteps 93, Score: -23.95, Avg.Score: -21.12, Run.Score -0.63, Time: 00:00:59
# Ep. 3, Ep.Timesteps 93, Score: -23.90, Avg.Score: -21.81, Run.Score -0.86, Time: 00:01:20
# Ep. 4, Ep.Timesteps 100, Score: 87.84, Avg.Score: 0.12, Run.Score 0.03, Time: 00:01:42
# Ep. 5, Ep.Timesteps 100, Score: 99.32, Avg.Score: 16.65, Run.Score 1.02, Time: 00:02:04
# Ep. 6, Ep.Timesteps 80, Score: -17.91, Avg.Score: 11.71, Run.Score 0.83, Time: 00:02:22
# Ep. 7, Ep.Timesteps 88, Score: -26.42, Avg.Score: 6.94, Run.Score 0.56, Time: 00:02:42
# Ep. 8, Ep.Timesteps 91, Score: -23.52, Avg.Score: 3.56, Run.Score 0.32, Time: 00:03:03
# Ep. 9, Ep.Timesteps 88, Score: -24.21, Avg.Score: 0.78, Run.Score 0.07, Time: 00:03:23
# Ep. 10, Ep.Timesteps 84, Score: -23.18, Avg.Score: -1.40, Run.Score -0.16, Time: 00:03:43
# Ep. 11, Ep.Timesteps 100, Score: 85.62, Avg.Score: 5.86, Run.Score 0.70, Time: 00:04:05
# Ep. 12, Ep.Timesteps 100, Score: 96.46, Avg.Score: 12.83, Run.Score 1.65, Time: 00:04:28
# Ep. 13, Ep.Timesteps 100, Score: 90.23, Avg.Score: 18.35, Run.Score 2.54, Time: 00:04:50
# Ep. 14, Ep.Timesteps 99, Score: -17.83, Avg.Score: 15.94, Run.Score 2.34, Time: 00:05:10
# Ep. 15, Ep.Timesteps 98, Score: -17.99, Avg.Score: 13.82, Run.Score 2.13, Time: 00:05:31
# Ep. 16, Ep.Timesteps 90, Score: -19.86, Avg.Score: 11.84, Run.Score 1.91, Time: 00:05:51
# Ep. 17, Ep.Timesteps 79, Score: -16.06, Avg.Score: 10.29, Run.Score 1.73, Time: 00:06:08
# Ep. 18, Ep.Timesteps 100, Score: 86.96, Avg.Score: 14.33, Run.Score 2.59, Time: 00:06:30
# Ep. 19, Ep.Timesteps 80, Score: -17.94, Avg.Score: 12.71, Run.Score 2.38, Time: 00:06:48
# Ep. 20, Ep.Timesteps 77, Score: -17.86, Avg.Score: 11.26, Run.Score 2.18, Time: 00:07:06
# updating
# Ep. 21, Ep.Timesteps 100, Score: 98.54, Avg.Score: 15.22, Run.Score 3.14, Time: 00:09:42
# Ep. 22, Ep.Timesteps 100, Score: 82.03, Avg.Score: 18.13, Run.Score 3.93, Time: 00:10:03
# Ep. 23, Ep.Timesteps 100, Score: 94.55, Avg.Score: 21.31, Run.Score 4.84, Time: 00:10:24
# Ep. 24, Ep.Timesteps 100, Score: -17.86, Avg.Score: 19.75, Run.Score 4.61, Time: 00:10:46
# Ep. 25, Ep.Timesteps 93, Score: -18.09, Avg.Score: 18.29, Run.Score 4.38, Time: 00:11:05
# Ep. 26, Ep.Timesteps 89, Score: -21.32, Avg.Score: 16.82, Run.Score 4.13, Time: 00:11:27
# Ep. 27, Ep.Timesteps 100, Score: 101.05, Avg.Score: 19.83, Run.Score 5.10, Time: 00:11:49
# Ep. 28, Ep.Timesteps 96, Score: -26.62, Avg.Score: 18.23, Run.Score 4.78, Time: 00:12:11
# Ep. 29, Ep.Timesteps 92, Score: -17.96, Avg.Score: 17.02, Run.Score 4.55, Time: 00:12:31
# Ep. 30, Ep.Timesteps 80, Score: -18.01, Avg.Score: 15.89, Run.Score 4.33, Time: 00:12:49
# Ep. 31, Ep.Timesteps 83, Score: -13.45, Avg.Score: 14.98, Run.Score 4.15, Time: 00:13:08
# Ep. 32, Ep.Timesteps 80, Score: -17.81, Avg.Score: 13.98, Run.Score 3.93, Time: 00:13:29
# Ep. 33, Ep.Timesteps 100, Score: 85.91, Avg.Score: 16.10, Run.Score 4.75, Time: 00:13:52
# Ep. 34, Ep.Timesteps 84, Score: -4.30, Avg.Score: 15.52, Run.Score 4.66, Time: 00:14:10
# Ep. 35, Ep.Timesteps 86, Score: -18.03, Avg.Score: 14.58, Run.Score 4.43, Time: 00:14:29
# Ep. 36, Ep.Timesteps 95, Score: -17.53, Avg.Score: 13.72, Run.Score 4.21, Time: 00:14:51
# Ep. 37, Ep.Timesteps 88, Score: -11.91, Avg.Score: 13.04, Run.Score 4.05, Time: 00:15:10
# Ep. 38, Ep.Timesteps 97, Score: -18.05, Avg.Score: 12.24, Run.Score 3.83, Time: 00:15:32
# Ep. 39, Ep.Timesteps 100, Score: 88.82, Avg.Score: 14.16, Run.Score 4.68, Time: 00:15:55
# Ep. 40, Ep.Timesteps 90, Score: -17.92, Avg.Score: 13.38, Run.Score 4.45, Time: 00:16:16
# Ep. 41, Ep.Timesteps 100, Score: 96.22, Avg.Score: 15.35, Run.Score 5.37, Time: 00:16:39
# Ep. 42, Ep.Timesteps 84, Score: -17.99, Avg.Score: 14.57, Run.Score 5.14, Time: 00:16:58
# updating
# Ep. 43, Ep.Timesteps 94, Score: -19.07, Avg.Score: 13.81, Run.Score 4.89, Time: 00:19:38
# Ep. 44, Ep.Timesteps 88, Score: -13.30, Avg.Score: 13.21, Run.Score 4.71, Time: 00:19:58
# Ep. 45, Ep.Timesteps 79, Score: -17.91, Avg.Score: 12.53, Run.Score 4.49, Time: 00:20:16
# Ep. 46, Ep.Timesteps 82, Score: -6.57, Avg.Score: 12.12, Run.Score 4.38, Time: 00:20:35
# Ep. 47, Ep.Timesteps 90, Score: -25.68, Avg.Score: 11.34, Run.Score 4.08, Time: 00:20:56
# Ep. 48, Ep.Timesteps 93, Score: -17.97, Avg.Score: 10.74, Run.Score 3.85, Time: 00:21:15
# Ep. 49, Ep.Timesteps 100, Score: 84.87, Avg.Score: 12.22, Run.Score 4.66, Time: 00:21:37
# Ep. 50, Ep.Timesteps 88, Score: -19.30, Avg.Score: 11.60, Run.Score 4.43, Time: 00:21:57
# Ep. 51, Ep.Timesteps 96, Score: -15.41, Avg.Score: 11.08, Run.Score 4.23, Time: 00:22:18
# Ep. 52, Ep.Timesteps 89, Score: -17.99, Avg.Score: 10.53, Run.Score 4.00, Time: 00:22:38
# Ep. 53, Ep.Timesteps 100, Score: 112.90, Avg.Score: 12.43, Run.Score 5.09, Time: 00:22:59
# Ep. 54, Ep.Timesteps 88, Score: -13.22, Avg.Score: 11.96, Run.Score 4.91, Time: 00:23:18
# Ep. 55, Ep.Timesteps 72, Score: -18.01, Avg.Score: 11.43, Run.Score 4.68, Time: 00:23:34
# Ep. 56, Ep.Timesteps 95, Score: -16.08, Avg.Score: 10.95, Run.Score 4.47, Time: 00:23:56
# Ep. 57, Ep.Timesteps 91, Score: -17.97, Avg.Score: 10.45, Run.Score 4.25, Time: 00:24:15
# Ep. 58, Ep.Timesteps 81, Score: -9.42, Avg.Score: 10.11, Run.Score 4.11, Time: 00:24:33
# Ep. 59, Ep.Timesteps 94, Score: -18.04, Avg.Score: 9.64, Run.Score 3.89, Time: 00:24:55
# Ep. 60, Ep.Timesteps 100, Score: 113.55, Avg.Score: 11.34, Run.Score 4.99, Time: 00:25:17
# Ep. 61, Ep.Timesteps 94, Score: -17.95, Avg.Score: 10.87, Run.Score 4.76, Time: 00:25:37
# Ep. 62, Ep.Timesteps 81, Score: -17.82, Avg.Score: 10.42, Run.Score 4.53, Time: 00:25:55
# Ep. 63, Ep.Timesteps 89, Score: -18.09, Avg.Score: 9.97, Run.Score 4.31, Time: 00:26:16
# Ep. 64, Ep.Timesteps 100, Score: 103.20, Avg.Score: 11.41, Run.Score 5.30, Time: 00:26:38
# updating
# Ep. 65, Ep.Timesteps 99, Score: -18.06, Avg.Score: 10.96, Run.Score 5.06, Time: 00:29:09
# Ep. 66, Ep.Timesteps 94, Score: -17.95, Avg.Score: 10.53, Run.Score 4.83, Time: 00:29:29
# Ep. 67, Ep.Timesteps 75, Score: -18.06, Avg.Score: 10.11, Run.Score 4.60, Time: 00:29:47
# Ep. 68, Ep.Timesteps 78, Score: -17.97, Avg.Score: 9.70, Run.Score 4.38, Time: 00:30:05
# Ep. 69, Ep.Timesteps 100, Score: 121.21, Avg.Score: 11.29, Run.Score 5.55, Time: 00:30:26
# Ep. 70, Ep.Timesteps 92, Score: -17.94, Avg.Score: 10.88, Run.Score 5.31, Time: 00:30:46
# Ep. 71, Ep.Timesteps 91, Score: -17.87, Avg.Score: 10.48, Run.Score 5.08, Time: 00:31:05
# Ep. 72, Ep.Timesteps 94, Score: -18.05, Avg.Score: 10.09, Run.Score 4.85, Time: 00:31:27
# Ep. 73, Ep.Timesteps 96, Score: -15.25, Avg.Score: 9.75, Run.Score 4.65, Time: 00:31:48
# Ep. 74, Ep.Timesteps 88, Score: -18.07, Avg.Score: 9.38, Run.Score 4.42, Time: 00:32:06
# Ep. 75, Ep.Timesteps 87, Score: -14.95, Avg.Score: 9.06, Run.Score 4.23, Time: 00:32:26
# Ep. 76, Ep.Timesteps 74, Score: -17.84, Avg.Score: 8.71, Run.Score 4.00, Time: 00:32:43
# Ep. 77, Ep.Timesteps 76, Score: -18.05, Avg.Score: 8.37, Run.Score 3.78, Time: 00:32:59
# Ep. 78, Ep.Timesteps 100, Score: 107.27, Avg.Score: 9.62, Run.Score 4.82, Time: 00:33:22
# Ep. 79, Ep.Timesteps 100, Score: 96.10, Avg.Score: 10.70, Run.Score 5.73, Time: 00:33:46
# Ep. 80, Ep.Timesteps 59, Score: -18.03, Avg.Score: 10.34, Run.Score 5.49, Time: 00:33:59
# Ep. 81, Ep.Timesteps 92, Score: -13.61, Avg.Score: 10.05, Run.Score 5.30, Time: 00:34:19
# Ep. 82, Ep.Timesteps 86, Score: -17.88, Avg.Score: 9.72, Run.Score 5.07, Time: 00:34:39
# Ep. 83, Ep.Timesteps 87, Score: -17.97, Avg.Score: 9.39, Run.Score 4.84, Time: 00:35:00
# Ep. 84, Ep.Timesteps 27, Score: 0.66, Avg.Score: 9.28, Run.Score 4.80, Time: 00:35:06
# Ep. 85, Ep.Timesteps 78, Score: -18.03, Avg.Score: 8.97, Run.Score 4.57, Time: 00:35:24
# Ep. 86, Ep.Timesteps 90, Score: -18.01, Avg.Score: 8.66, Run.Score 4.34, Time: 00:35:44
# Ep. 87, Ep.Timesteps 100, Score: 89.97, Avg.Score: 9.58, Run.Score 5.20, Time: 00:36:07
# Ep. 88, Ep.Timesteps 93, Score: -17.90, Avg.Score: 9.27, Run.Score 4.97, Time: 00:36:27
# updating
# Ep. 89, Ep.Timesteps 95, Score: -23.85, Avg.Score: 8.90, Run.Score 4.68, Time: 00:39:02
# Ep. 90, Ep.Timesteps 87, Score: -15.61, Avg.Score: 8.63, Run.Score 4.48, Time: 00:39:22
# Ep. 91, Ep.Timesteps 84, Score: -4.96, Avg.Score: 8.49, Run.Score 4.38, Time: 00:39:41
# Ep. 92, Ep.Timesteps 94, Score: -17.84, Avg.Score: 8.20, Run.Score 4.16, Time: 00:40:02
# Ep. 93, Ep.Timesteps 63, Score: 11.43, Avg.Score: 8.24, Run.Score 4.24, Time: 00:40:15
# Ep. 94, Ep.Timesteps 83, Score: -17.81, Avg.Score: 7.96, Run.Score 4.01, Time: 00:40:36
# Ep. 95, Ep.Timesteps 81, Score: -17.84, Avg.Score: 7.69, Run.Score 3.80, Time: 00:40:55
# Ep. 96, Ep.Timesteps 100, Score: 82.76, Avg.Score: 8.47, Run.Score 4.59, Time: 00:41:17
# Ep. 97, Ep.Timesteps 83, Score: -5.87, Avg.Score: 8.32, Run.Score 4.48, Time: 00:41:36
# Ep. 98, Ep.Timesteps 93, Score: -17.87, Avg.Score: 8.06, Run.Score 4.26, Time: 00:41:56
# Ep. 99, Ep.Timesteps 86, Score: -18.06, Avg.Score: 7.80, Run.Score 4.03, Time: 00:42:16
# Ep. 100, Ep.Timesteps 100, Score: 90.91, Avg.Score: 8.92, Run.Score 4.90, Time: 00:42:38
# Ep. 101, Ep.Timesteps 83, Score: -9.17, Avg.Score: 9.01, Run.Score 4.76, Time: 00:42:56
# Ep. 102, Ep.Timesteps 84, Score: -18.01, Avg.Score: 9.07, Run.Score 4.53, Time: 00:43:15
# Ep. 103, Ep.Timesteps 100, Score: 124.51, Avg.Score: 10.55, Run.Score 5.73, Time: 00:43:37
# Ep. 104, Ep.Timesteps 95, Score: -10.81, Avg.Score: 9.56, Run.Score 5.57, Time: 00:43:58
# Ep. 105, Ep.Timesteps 82, Score: -18.08, Avg.Score: 8.39, Run.Score 5.33, Time: 00:44:17
# Ep. 106, Ep.Timesteps 93, Score: -16.44, Avg.Score: 8.40, Run.Score 5.11, Time: 00:44:39
# Ep. 107, Ep.Timesteps 52, Score: 11.49, Avg.Score: 8.78, Run.Score 5.18, Time: 00:44:49
# Ep. 108, Ep.Timesteps 73, Score: -17.98, Avg.Score: 8.84, Run.Score 4.95, Time: 00:45:06
# Ep. 109, Ep.Timesteps 88, Score: -18.06, Avg.Score: 8.90, Run.Score 4.72, Time: 00:45:26
# Ep. 110, Ep.Timesteps 96, Score: -17.99, Avg.Score: 8.95, Run.Score 4.49, Time: 00:45:47
# Ep. 111, Ep.Timesteps 78, Score: -11.38, Avg.Score: 7.98, Run.Score 4.33, Time: 00:46:05
# updating
# Ep. 112, Ep.Timesteps 100, Score: 116.84, Avg.Score: 8.19, Run.Score 5.46, Time: 00:48:29
# Ep. 113, Ep.Timesteps 100, Score: 84.51, Avg.Score: 8.13, Run.Score 6.25, Time: 00:48:51
# Ep. 114, Ep.Timesteps 64, Score: 9.09, Avg.Score: 8.40, Run.Score 6.28, Time: 00:49:05
# Ep. 115, Ep.Timesteps 82, Score: -12.28, Avg.Score: 8.46, Run.Score 6.09, Time: 00:49:23
# Ep. 116, Ep.Timesteps 76, Score: -4.88, Avg.Score: 8.61, Run.Score 5.98, Time: 00:49:40
# Ep. 117, Ep.Timesteps 61, Score: 23.51, Avg.Score: 9.00, Run.Score 6.16, Time: 00:49:54
# Ep. 118, Ep.Timesteps 100, Score: 99.68, Avg.Score: 9.13, Run.Score 7.09, Time: 00:50:18
# Ep. 119, Ep.Timesteps 87, Score: -17.98, Avg.Score: 9.13, Run.Score 6.84, Time: 00:50:38
# Ep. 120, Ep.Timesteps 87, Score: -18.10, Avg.Score: 9.13, Run.Score 6.59, Time: 00:50:57
# Ep. 121, Ep.Timesteps 92, Score: -17.98, Avg.Score: 7.96, Run.Score 6.34, Time: 00:51:19
# Ep. 122, Ep.Timesteps 78, Score: -17.96, Avg.Score: 6.96, Run.Score 6.10, Time: 00:51:39
# Ep. 123, Ep.Timesteps 86, Score: -17.94, Avg.Score: 5.84, Run.Score 5.86, Time: 00:51:58
# Ep. 124, Ep.Timesteps 89, Score: 19.91, Avg.Score: 6.21, Run.Score 6.00, Time: 00:52:17
# Ep. 125, Ep.Timesteps 100, Score: 102.48, Avg.Score: 7.42, Run.Score 6.97, Time: 00:52:41
# Ep. 126, Ep.Timesteps 72, Score: 7.30, Avg.Score: 7.71, Run.Score 6.97, Time: 00:52:56
# Ep. 127, Ep.Timesteps 70, Score: 2.91, Avg.Score: 6.72, Run.Score 6.93, Time: 00:53:11
# Ep. 128, Ep.Timesteps 93, Score: -18.02, Avg.Score: 6.81, Run.Score 6.68, Time: 00:53:33
# Ep. 129, Ep.Timesteps 96, Score: -18.02, Avg.Score: 6.81, Run.Score 6.43, Time: 00:53:55
# Ep. 130, Ep.Timesteps 94, Score: -17.96, Avg.Score: 6.81, Run.Score 6.19, Time: 00:54:16
# Ep. 131, Ep.Timesteps 69, Score: 8.33, Avg.Score: 7.03, Run.Score 6.21, Time: 00:54:30
# Ep. 132, Ep.Timesteps 83, Score: -18.09, Avg.Score: 7.02, Run.Score 5.97, Time: 00:54:50
# Ep. 133, Ep.Timesteps 91, Score: -18.09, Avg.Score: 5.98, Run.Score 5.73, Time: 00:55:11
# Ep. 134, Ep.Timesteps 90, Score: -16.36, Avg.Score: 5.86, Run.Score 5.51, Time: 00:55:32
# Ep. 135, Ep.Timesteps 72, Score: -17.95, Avg.Score: 5.86, Run.Score 5.27, Time: 00:55:49
# updating
# Ep. 136, Ep.Timesteps 74, Score: -8.83, Avg.Score: 5.95, Run.Score 5.13, Time: 00:58:16
# Ep. 137, Ep.Timesteps 61, Score: 14.67, Avg.Score: 6.22, Run.Score 5.23, Time: 00:58:29
# Ep. 138, Ep.Timesteps 36, Score: 8.18, Avg.Score: 6.48, Run.Score 5.26, Time: 00:58:37
# Ep. 139, Ep.Timesteps 61, Score: -18.04, Avg.Score: 5.41, Run.Score 5.02, Time: 00:58:51
# Ep. 140, Ep.Timesteps 94, Score: -18.01, Avg.Score: 5.41, Run.Score 4.79, Time: 00:59:11
# Ep. 141, Ep.Timesteps 73, Score: 9.08, Avg.Score: 4.54, Run.Score 4.83, Time: 00:59:29
# Ep. 142, Ep.Timesteps 91, Score: 33.09, Avg.Score: 5.05, Run.Score 5.12, Time: 00:59:50
# Ep. 143, Ep.Timesteps 81, Score: -17.91, Avg.Score: 5.06, Run.Score 4.89, Time: 01:00:09
# Ep. 144, Ep.Timesteps 79, Score: -18.09, Avg.Score: 5.01, Run.Score 4.66, Time: 01:00:27
# Ep. 145, Ep.Timesteps 26, Score: 15.97, Avg.Score: 5.35, Run.Score 4.77, Time: 01:00:33
# Ep. 146, Ep.Timesteps 63, Score: -17.92, Avg.Score: 5.24, Run.Score 4.54, Time: 01:00:47
# Ep. 147, Ep.Timesteps 82, Score: -18.07, Avg.Score: 5.32, Run.Score 4.32, Time: 01:01:05
# Ep. 148, Ep.Timesteps 74, Score: 2.91, Avg.Score: 5.52, Run.Score 4.30, Time: 01:01:21
# Ep. 149, Ep.Timesteps 84, Score: -18.03, Avg.Score: 4.49, Run.Score 4.08, Time: 01:01:40
# Ep. 150, Ep.Timesteps 60, Score: -17.93, Avg.Score: 4.51, Run.Score 3.86, Time: 01:01:54
# Ep. 151, Ep.Timesteps 66, Score: -18.03, Avg.Score: 4.48, Run.Score 3.64, Time: 01:02:08
# Ep. 152, Ep.Timesteps 66, Score: 3.68, Avg.Score: 4.70, Run.Score 3.64, Time: 01:02:23
# Ep. 153, Ep.Timesteps 100, Score: 112.32, Avg.Score: 4.69, Run.Score 4.73, Time: 01:02:44
# Ep. 154, Ep.Timesteps 93, Score: -17.93, Avg.Score: 4.65, Run.Score 4.50, Time: 01:03:05
# Ep. 155, Ep.Timesteps 95, Score: -18.04, Avg.Score: 4.65, Run.Score 4.28, Time: 01:03:25
# Ep. 156, Ep.Timesteps 100, Score: 82.57, Avg.Score: 5.63, Run.Score 5.06, Time: 01:03:49
# Ep. 157, Ep.Timesteps 79, Score: -17.91, Avg.Score: 5.63, Run.Score 4.83, Time: 01:04:07
# Ep. 158, Ep.Timesteps 81, Score: -18.06, Avg.Score: 5.55, Run.Score 4.60, Time: 01:04:25
# Ep. 159, Ep.Timesteps 79, Score: -18.09, Avg.Score: 5.55, Run.Score 4.37, Time: 01:04:42
# Ep. 160, Ep.Timesteps 91, Score: -17.56, Avg.Score: 4.23, Run.Score 4.15, Time: 01:05:03
# Ep. 161, Ep.Timesteps 36, Score: 9.48, Avg.Score: 4.51, Run.Score 4.21, Time: 01:05:11
# Ep. 162, Ep.Timesteps 75, Score: -5.18, Avg.Score: 4.64, Run.Score 4.11, Time: 01:05:29
# updating
# Ep. 163, Ep.Timesteps 59, Score: 17.74, Avg.Score: 4.99, Run.Score 4.25, Time: 01:07:53
# Ep. 164, Ep.Timesteps 72, Score: -12.63, Avg.Score: 3.84, Run.Score 4.08, Time: 01:08:10
# Ep. 165, Ep.Timesteps 71, Score: -3.31, Avg.Score: 3.98, Run.Score 4.01, Time: 01:08:26
# Ep. 166, Ep.Timesteps 76, Score: -17.97, Avg.Score: 3.98, Run.Score 3.79, Time: 01:08:44
# Ep. 167, Ep.Timesteps 100, Score: 132.62, Avg.Score: 5.49, Run.Score 5.08, Time: 01:09:06
# Ep. 168, Ep.Timesteps 100, Score: 138.21, Avg.Score: 7.05, Run.Score 6.41, Time: 01:09:26
# Ep. 169, Ep.Timesteps 81, Score: -18.01, Avg.Score: 5.66, Run.Score 6.16, Time: 01:09:46
# Ep. 170, Ep.Timesteps 93, Score: -18.07, Avg.Score: 5.66, Run.Score 5.92, Time: 01:10:07
# Ep. 171, Ep.Timesteps 80, Score: -18.10, Avg.Score: 5.66, Run.Score 5.68, Time: 01:10:26
# Ep. 172, Ep.Timesteps 51, Score: 10.02, Avg.Score: 5.94, Run.Score 5.72, Time: 01:10:39
# Ep. 173, Ep.Timesteps 52, Score: 18.45, Avg.Score: 6.27, Run.Score 5.85, Time: 01:10:50
# Ep. 174, Ep.Timesteps 55, Score: 15.87, Avg.Score: 6.61, Run.Score 5.95, Time: 01:11:02
# Ep. 175, Ep.Timesteps 55, Score: 15.48, Avg.Score: 6.92, Run.Score 6.05, Time: 01:11:14
# Ep. 176, Ep.Timesteps 61, Score: 8.00, Avg.Score: 7.18, Run.Score 6.07, Time: 01:11:28
# Ep. 177, Ep.Timesteps 33, Score: 18.85, Avg.Score: 7.54, Run.Score 6.19, Time: 01:11:35
# Ep. 178, Ep.Timesteps 81, Score: -18.09, Avg.Score: 6.29, Run.Score 5.95, Time: 01:11:55
# Ep. 179, Ep.Timesteps 62, Score: 18.82, Avg.Score: 5.52, Run.Score 6.08, Time: 01:12:09
# Ep. 180, Ep.Timesteps 72, Score: -18.09, Avg.Score: 5.52, Run.Score 5.84, Time: 01:12:25
# Ep. 181, Ep.Timesteps 78, Score: -18.10, Avg.Score: 5.47, Run.Score 5.60, Time: 01:12:44
# Ep. 182, Ep.Timesteps 92, Score: 8.02, Avg.Score: 5.73, Run.Score 5.62, Time: 01:13:05
# Ep. 183, Ep.Timesteps 47, Score: -14.79, Avg.Score: 5.76, Run.Score 5.42, Time: 01:13:15
# Ep. 184, Ep.Timesteps 93, Score: -17.91, Avg.Score: 5.58, Run.Score 5.19, Time: 01:13:36
# Ep. 185, Ep.Timesteps 64, Score: -3.34, Avg.Score: 5.72, Run.Score 5.10, Time: 01:13:51
# Ep. 186, Ep.Timesteps 53, Score: 1.39, Avg.Score: 5.92, Run.Score 5.06, Time: 01:14:03
# Ep. 187, Ep.Timesteps 82, Score: -18.04, Avg.Score: 4.84, Run.Score 4.83, Time: 01:14:21
# Ep. 188, Ep.Timesteps 99, Score: -17.95, Avg.Score: 4.84, Run.Score 4.60, Time: 01:14:46
# Ep. 189, Ep.Timesteps 100, Score: 127.09, Avg.Score: 6.35, Run.Score 5.83, Time: 01:15:08
# updating
# Ep. 190, Ep.Timesteps 87, Score: -18.01, Avg.Score: 6.32, Run.Score 5.59, Time: 01:17:48
# Ep. 191, Ep.Timesteps 100, Score: 136.03, Avg.Score: 7.73, Run.Score 6.90, Time: 01:18:11
# Ep. 192, Ep.Timesteps 60, Score: 16.71, Avg.Score: 8.08, Run.Score 6.99, Time: 01:18:24
# Ep. 193, Ep.Timesteps 62, Score: 12.47, Avg.Score: 8.09, Run.Score 7.05, Time: 01:18:38
# Ep. 194, Ep.Timesteps 81, Score: 14.59, Avg.Score: 8.41, Run.Score 7.12, Time: 01:18:55
# Ep. 195, Ep.Timesteps 66, Score: 9.37, Avg.Score: 8.69, Run.Score 7.15, Time: 01:19:09
# Ep. 196, Ep.Timesteps 100, Score: 146.52, Avg.Score: 9.32, Run.Score 8.54, Time: 01:19:32
# Ep. 197, Ep.Timesteps 55, Score: 19.30, Avg.Score: 9.57, Run.Score 8.65, Time: 01:19:45
# Ep. 198, Ep.Timesteps 58, Score: 20.12, Avg.Score: 9.95, Run.Score 8.76, Time: 01:19:57
# Ep. 199, Ep.Timesteps 74, Score: -18.08, Avg.Score: 9.95, Run.Score 8.49, Time: 01:20:12
# Ep. 200, Ep.Timesteps 58, Score: 16.22, Avg.Score: 9.21, Run.Score 8.57, Time: 01:20:26
# Ep. 201, Ep.Timesteps 87, Score: -17.93, Avg.Score: 9.12, Run.Score 8.31, Time: 01:20:45
# Ep. 202, Ep.Timesteps 55, Score: 10.35, Avg.Score: 9.40, Run.Score 8.33, Time: 01:20:58
# Ep. 203, Ep.Timesteps 80, Score: -17.91, Avg.Score: 7.98, Run.Score 8.06, Time: 01:21:17
# Ep. 204, Ep.Timesteps 76, Score: 9.63, Avg.Score: 8.18, Run.Score 8.08, Time: 01:21:34
# Ep. 205, Ep.Timesteps 64, Score: 13.54, Avg.Score: 8.50, Run.Score 8.13, Time: 01:21:49
# Ep. 206, Ep.Timesteps 97, Score: -18.01, Avg.Score: 8.48, Run.Score 7.87, Time: 01:22:10
# Ep. 207, Ep.Timesteps 61, Score: -17.98, Avg.Score: 8.19, Run.Score 7.61, Time: 01:22:24
# Ep. 208, Ep.Timesteps 48, Score: 25.28, Avg.Score: 8.62, Run.Score 7.79, Time: 01:22:34
# Ep. 209, Ep.Timesteps 86, Score: -18.06, Avg.Score: 8.62, Run.Score 7.53, Time: 01:22:53
# Ep. 210, Ep.Timesteps 59, Score: 30.61, Avg.Score: 9.11, Run.Score 7.76, Time: 01:23:06
# Ep. 211, Ep.Timesteps 79, Score: -18.00, Avg.Score: 9.04, Run.Score 7.51, Time: 01:23:23
# Ep. 212, Ep.Timesteps 54, Score: 16.34, Avg.Score: 8.04, Run.Score 7.59, Time: 01:23:35
# Ep. 213, Ep.Timesteps 39, Score: 9.37, Avg.Score: 7.29, Run.Score 7.61, Time: 01:23:43
# Ep. 214, Ep.Timesteps 89, Score: -12.28, Avg.Score: 7.07, Run.Score 7.41, Time: 01:24:03
# Ep. 215, Ep.Timesteps 59, Score: 16.33, Avg.Score: 7.36, Run.Score 7.50, Time: 01:24:16
# Ep. 216, Ep.Timesteps 60, Score: 8.02, Avg.Score: 7.49, Run.Score 7.51, Time: 01:24:29
# Ep. 217, Ep.Timesteps 61, Score: 8.17, Avg.Score: 7.33, Run.Score 7.51, Time: 01:24:43
# Ep. 218, Ep.Timesteps 59, Score: 14.31, Avg.Score: 6.48, Run.Score 7.58, Time: 01:24:56
# updating
# Ep. 219, Ep.Timesteps 39, Score: 9.22, Avg.Score: 6.75, Run.Score 7.60, Time: 01:27:04
# Ep. 220, Ep.Timesteps 54, Score: 12.90, Avg.Score: 7.06, Run.Score 7.65, Time: 01:27:24
# Ep. 221, Ep.Timesteps 33, Score: 2.27, Avg.Score: 7.26, Run.Score 7.60, Time: 01:27:33
# Ep. 222, Ep.Timesteps 84, Score: -18.08, Avg.Score: 7.26, Run.Score 7.34, Time: 01:27:52
# Ep. 223, Ep.Timesteps 100, Score: 151.52, Avg.Score: 8.96, Run.Score 8.78, Time: 01:28:14
# Ep. 224, Ep.Timesteps 55, Score: 11.32, Avg.Score: 8.87, Run.Score 8.81, Time: 01:28:26
# Ep. 225, Ep.Timesteps 65, Score: 18.74, Avg.Score: 8.03, Run.Score 8.91, Time: 01:28:41
# Ep. 226, Ep.Timesteps 79, Score: -15.84, Avg.Score: 7.80, Run.Score 8.66, Time: 01:28:59
# Ep. 227, Ep.Timesteps 79, Score: 11.54, Avg.Score: 7.89, Run.Score 8.69, Time: 01:29:18
# Ep. 228, Ep.Timesteps 57, Score: 18.29, Avg.Score: 8.25, Run.Score 8.78, Time: 01:29:30
# Ep. 229, Ep.Timesteps 100, Score: 141.89, Avg.Score: 9.85, Run.Score 10.12, Time: 01:29:53
# Ep. 230, Ep.Timesteps 89, Score: 48.60, Avg.Score: 10.52, Run.Score 10.50, Time: 01:30:13
# Ep. 231, Ep.Timesteps 48, Score: -8.38, Avg.Score: 10.35, Run.Score 10.31, Time: 01:30:24
# Ep. 232, Ep.Timesteps 46, Score: 10.46, Avg.Score: 10.64, Run.Score 10.31, Time: 01:30:34
# Ep. 233, Ep.Timesteps 80, Score: -12.24, Avg.Score: 10.69, Run.Score 10.09, Time: 01:30:52
# Ep. 234, Ep.Timesteps 100, Score: 151.72, Avg.Score: 12.37, Run.Score 11.50, Time: 01:31:14
# Ep. 235, Ep.Timesteps 59, Score: 14.22, Avg.Score: 12.70, Run.Score 11.53, Time: 01:31:27
# Ep. 236, Ep.Timesteps 78, Score: -17.84, Avg.Score: 12.61, Run.Score 11.24, Time: 01:31:45
# Ep. 237, Ep.Timesteps 63, Score: 17.28, Avg.Score: 12.63, Run.Score 11.30, Time: 01:31:59
# Ep. 238, Ep.Timesteps 36, Score: 8.86, Avg.Score: 12.64, Run.Score 11.27, Time: 01:32:07
# Ep. 239, Ep.Timesteps 63, Score: -1.56, Avg.Score: 12.80, Run.Score 11.14, Time: 01:32:22
# Ep. 240, Ep.Timesteps 28, Score: 10.34, Avg.Score: 13.09, Run.Score 11.14, Time: 01:32:28
# Ep. 241, Ep.Timesteps 79, Score: -17.92, Avg.Score: 12.82, Run.Score 10.85, Time: 01:32:47
# Ep. 242, Ep.Timesteps 53, Score: 23.11, Avg.Score: 12.72, Run.Score 10.97, Time: 01:32:58
# Ep. 243, Ep.Timesteps 100, Score: 130.00, Avg.Score: 14.20, Run.Score 12.16, Time: 01:33:20
# Ep. 244, Ep.Timesteps 54, Score: 12.93, Avg.Score: 14.51, Run.Score 12.17, Time: 01:33:33
# Ep. 245, Ep.Timesteps 77, Score: 0.27, Avg.Score: 14.35, Run.Score 12.05, Time: 01:33:49
# Ep. 246, Ep.Timesteps 46, Score: 12.48, Avg.Score: 14.65, Run.Score 12.05, Time: 01:33:59
# Ep. 247, Ep.Timesteps 49, Score: -17.92, Avg.Score: 14.66, Run.Score 11.75, Time: 01:34:11
# Ep. 248, Ep.Timesteps 61, Score: -18.00, Avg.Score: 14.45, Run.Score 11.45, Time: 01:34:24
# Ep. 249, Ep.Timesteps 61, Score: 21.45, Avg.Score: 14.84, Run.Score 11.55, Time: 01:34:38
# updating
# Ep. 250, Ep.Timesteps 55, Score: 15.28, Avg.Score: 15.17, Run.Score 11.59, Time: 01:36:51
# Ep. 251, Ep.Timesteps 94, Score: -18.06, Avg.Score: 15.17, Run.Score 11.30, Time: 01:37:11
# Ep. 252, Ep.Timesteps 54, Score: 19.63, Avg.Score: 15.33, Run.Score 11.38, Time: 01:37:23
# Ep. 253, Ep.Timesteps 44, Score: -18.00, Avg.Score: 14.03, Run.Score 11.09, Time: 01:37:41
# Ep. 254, Ep.Timesteps 53, Score: 8.10, Avg.Score: 14.29, Run.Score 11.06, Time: 01:37:54
# Ep. 255, Ep.Timesteps 91, Score: -20.70, Avg.Score: 14.26, Run.Score 10.74, Time: 01:38:15
# Ep. 256, Ep.Timesteps 43, Score: 17.37, Avg.Score: 13.61, Run.Score 10.80, Time: 01:38:25
# Ep. 257, Ep.Timesteps 69, Score: 11.37, Avg.Score: 13.90, Run.Score 10.81, Time: 01:38:40
# Ep. 258, Ep.Timesteps 67, Score: 20.41, Avg.Score: 14.29, Run.Score 10.91, Time: 01:38:55
# Ep. 259, Ep.Timesteps 83, Score: -17.08, Avg.Score: 14.30, Run.Score 10.63, Time: 01:39:14
# Ep. 260, Ep.Timesteps 80, Score: 17.49, Avg.Score: 14.65, Run.Score 10.69, Time: 01:39:33
# Ep. 261, Ep.Timesteps 59, Score: 13.61, Avg.Score: 14.69, Run.Score 10.72, Time: 01:39:47
# Ep. 262, Ep.Timesteps 73, Score: -18.08, Avg.Score: 14.56, Run.Score 10.44, Time: 01:40:04
# Ep. 263, Ep.Timesteps 52, Score: 10.24, Avg.Score: 14.49, Run.Score 10.43, Time: 01:40:16
# Ep. 264, Ep.Timesteps 46, Score: 31.21, Avg.Score: 14.92, Run.Score 10.64, Time: 01:40:25
# Ep. 265, Ep.Timesteps 62, Score: 13.36, Avg.Score: 15.09, Run.Score 10.67, Time: 01:40:40
# Ep. 266, Ep.Timesteps 48, Score: -18.00, Avg.Score: 15.09, Run.Score 10.38, Time: 01:40:51
# Ep. 267, Ep.Timesteps 85, Score: -17.83, Avg.Score: 13.59, Run.Score 10.10, Time: 01:41:11
# Ep. 268, Ep.Timesteps 91, Score: 28.43, Avg.Score: 12.49, Run.Score 10.28, Time: 01:41:31
# Ep. 269, Ep.Timesteps 59, Score: 8.54, Avg.Score: 12.75, Run.Score 10.27, Time: 01:41:45
# Ep. 270, Ep.Timesteps 58, Score: 8.29, Avg.Score: 13.02, Run.Score 10.25, Time: 01:41:58
# Ep. 271, Ep.Timesteps 29, Score: 8.32, Avg.Score: 13.28, Run.Score 10.23, Time: 01:42:05
# Ep. 272, Ep.Timesteps 57, Score: 19.56, Avg.Score: 13.38, Run.Score 10.32, Time: 01:42:17
# Ep. 273, Ep.Timesteps 74, Score: -9.82, Avg.Score: 13.09, Run.Score 10.12, Time: 01:42:33
# Ep. 274, Ep.Timesteps 35, Score: 8.89, Avg.Score: 13.02, Run.Score 10.11, Time: 01:42:42
# Ep. 275, Ep.Timesteps 78, Score: 15.27, Avg.Score: 13.02, Run.Score 10.16, Time: 01:42:59
# Ep. 276, Ep.Timesteps 37, Score: 15.10, Avg.Score: 13.09, Run.Score 10.21, Time: 01:43:07
# Ep. 277, Ep.Timesteps 41, Score: 14.04, Avg.Score: 13.05, Run.Score 10.25, Time: 01:43:17
# Ep. 278, Ep.Timesteps 70, Score: -18.05, Avg.Score: 13.05, Run.Score 9.96, Time: 01:43:34
# Ep. 279, Ep.Timesteps 41, Score: 14.15, Avg.Score: 13.00, Run.Score 10.00, Time: 01:43:43
# Ep. 280, Ep.Timesteps 47, Score: 14.39, Avg.Score: 13.32, Run.Score 10.05, Time: 01:43:53
# Ep. 281, Ep.Timesteps 59, Score: 12.17, Avg.Score: 13.63, Run.Score 10.07, Time: 01:44:06
# Ep. 282, Ep.Timesteps 56, Score: 18.42, Avg.Score: 13.73, Run.Score 10.15, Time: 01:44:18
# updating
# Ep. 283, Ep.Timesteps 63, Score: 21.52, Avg.Score: 14.09, Run.Score 10.27, Time: 01:46:37
# Ep. 284, Ep.Timesteps 76, Score: -18.02, Avg.Score: 14.09, Run.Score 9.98, Time: 01:46:54
# Ep. 285, Ep.Timesteps 66, Score: 11.04, Avg.Score: 14.24, Run.Score 9.99, Time: 01:47:08
# Ep. 286, Ep.Timesteps 73, Score: 11.01, Avg.Score: 14.33, Run.Score 10.00, Time: 01:47:25
# Ep. 287, Ep.Timesteps 46, Score: 12.23, Avg.Score: 14.64, Run.Score 10.03, Time: 01:47:35
# Ep. 288, Ep.Timesteps 63, Score: 22.43, Avg.Score: 15.04, Run.Score 10.15, Time: 01:47:55
# Ep. 289, Ep.Timesteps 59, Score: 22.17, Avg.Score: 13.99, Run.Score 10.27, Time: 01:48:08
# Ep. 290, Ep.Timesteps 33, Score: 12.71, Avg.Score: 14.30, Run.Score 10.30, Time: 01:48:15
# Ep. 291, Ep.Timesteps 63, Score: -17.98, Avg.Score: 12.76, Run.Score 10.01, Time: 01:48:30
# Ep. 292, Ep.Timesteps 53, Score: 13.95, Avg.Score: 12.73, Run.Score 10.05, Time: 01:48:42
# Ep. 293, Ep.Timesteps 35, Score: 17.55, Avg.Score: 12.78, Run.Score 10.13, Time: 01:48:50
# Ep. 294, Ep.Timesteps 25, Score: 20.24, Avg.Score: 12.84, Run.Score 10.23, Time: 01:48:56
# Ep. 295, Ep.Timesteps 32, Score: 12.22, Avg.Score: 12.87, Run.Score 10.25, Time: 01:49:03
# Ep. 296, Ep.Timesteps 82, Score: -17.14, Avg.Score: 11.23, Run.Score 9.97, Time: 01:49:21
# Ep. 297, Ep.Timesteps 78, Score: -18.01, Avg.Score: 10.86, Run.Score 9.69, Time: 01:49:40
# Ep. 298, Ep.Timesteps 44, Score: 24.82, Avg.Score: 10.90, Run.Score 9.85, Time: 01:49:49
# Ep. 299, Ep.Timesteps 51, Score: 23.17, Avg.Score: 11.32, Run.Score 9.98, Time: 01:50:00

# %%
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  300 , len of avg_scores:  300

# %%
def load(agent, directory, filename):
    agent.net.load_state_dict(torch.load(os.path.join(directory,filename)))

# %%
def play(env, agent, n_episodes):
    state = env_wrap.reset()
    
    scores_deque = deque(maxlen=n_episodes)
    scores = []
    
    for i_episode in range(1, n_episodes+1):
        state = env_wrap.reset()        
        score = 0
        
        time_start = time.time()
        
        while True:
            action, a_logp = agent.select_action(state)
            env.render()
            next_state, reward, done, die = env_wrap.step( \
                action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

            state = next_state
            score += reward
            
            if done or die:
                break 

        s = (int)(time.time() - time_start)
        
        scores_deque.append(score)
        scores.append(score)

        print('Episode {}\tAverage Score: {:.2f},\tScore: {:.2f} \tTime: {:02}:{:02}:{:02}'\
                  .format(i_episode, np.mean(scores_deque), score, s//3600, s%3600//60, s%60))
    return np.mean(scores_deque)

# %%
# We use the average score of 10 episodes as result, Don't change n_episodes!!!
total_avg_reward = play(env, agent, n_episodes=10)
# Out:
# Episode 1	Average Score: 11.49,	Score: 11.49 	Time: 00:00:06
# Episode 2	Average Score: 10.84,	Score: 10.20 	Time: 00:00:15
# Episode 3	Average Score: 1.20,	Score: -18.09 	Time: 00:00:11
# Episode 4	Average Score: 3.95,	Score: 12.19 	Time: 00:00:06
# Episode 5	Average Score: 7.65,	Score: 22.44 	Time: 00:00:11
# Episode 6	Average Score: 9.35,	Score: 17.85 	Time: 00:00:11
# Episode 7	Average Score: 9.61,	Score: 11.17 	Time: 00:00:10
# Episode 8	Average Score: 12.53,	Score: 33.02 	Time: 00:00:12
# Episode 9	Average Score: 13.01,	Score: 16.82 	Time: 00:00:16
# Episode 10	Average Score: 12.64,	Score: 9.32 	Time: 00:00:08

# %%
# Print results in CSV format and upload to Kaggle
with open('rewards.csv', 'w') as f:
    f.write('Id,Predicted\n')
    f.write('CarRacing_public,{}\n'.format(total_avg_reward))
    f.write('CarRacing_private,{}\n'.format(total_avg_reward))

# Download your results!
from IPython.display import FileLink
FileLink('rewards.csv')
# Out:
# /kaggle/working/rewards.csv

# %% [markdown]
# ## Show Your Training Result

# %%
import os
env_test = Monitor(gym.make("CarRacing-v0"), './video', force=True)
env_test.reset()
env_wrap = Wrapper(env_test)
load(agent, '', 'model_weights_latest.pth')
play(env_test, agent, n_episodes=1)
while True:
    env_test.render()
    action = env_test.action_space.sample() 
    observation, reward, done, info = env_test.step(action)         
    if done: 
      break;
env_test.close()
show_video()
# Out:
# Track generation: 1112..1403 -> 291-tiles track
# Episode 1	Average Score: 21.23,	Score: 21.23 	Time: 00:00:13
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
